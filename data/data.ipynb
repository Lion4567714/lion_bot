# %%
import discord
from discord import app_commands
import logging

import pymongo
import pymongo.errors
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

import sys
import urllib.parse

import pandas as pd

# %%
pd.set_option('display.max_rows', 25)

# %%
file = open('../config/mongo', 'r')
mongo = file.read().splitlines()
file.close()

mongo_user = urllib.parse.quote(mongo[0])
mongo_pass = urllib.parse.quote(mongo[1])

uri = f"mongodb+srv://{mongo_user}:{mongo_pass}@discordcluster.ujcowjs.mongodb.net/?retryWrites=true&w=majority"
mongo_client = MongoClient(uri, server_api=ServerApi('1'))

db = mongo_client.my_database
posts = db['posts']

# %%
df = pd.DataFrame(list(posts.find()))

# %%
df
# Out:
#                           _id                     content  \
# 0    65aec59ab34d51f31e7205e4                        test
# 1    65aec5a0b34d51f31e7205e5                      $hello
# 2    65aec5a1b34d51f31e7205e6                      Hello!
# 3    65aec961486a2b37a86a6859                      $hello
# 4    65aec961486a2b37a86a685a                      Hello!
# ..                        ...                         ...
# 977  65beebecb078e9ee076ef5b8                           😄
# 978  65beebecb078e9ee076ef5b9                        test
# 979  65beebedb078e9ee076ef5ba                   fucka you
# 980  65beebf7b078e9ee076ef5bb  oh wow a biggie cheese bot
# 981  65beebfeb078e9ee076ef5bc                That's fancy
#
#                       id author.global_name    author.name mention_everyone  \
# 0    1199077135063732365                NaN            NaN              NaN
# 1    1199077159969509407                NaN            NaN              NaN
# 2    1199077161085181995                NaN            NaN              NaN
# 3    1199081188468469860               Lion    lion4567714            False
# 4    1199081189739335680               None       Lion Bot            False
# ..                   ...                ...            ...              ...
# 977  1203516321191436298               Lion    lion4567714            False
# 978  1203516323519533086            Huskies        husk1es            False
# 979  1203516327650918444      TheBugMonster  thebugmonster            False
# 980  1203516368700440597            Huskies        husk1es            False
# 981  1203516398979125289            Huskies        husk1es            False
#
#     pinned reactions channel.name mentions role_mentions      guild.id  \
# 0      NaN       NaN          NaN      NaN           NaN           NaN
# 1      NaN       NaN          NaN      NaN           NaN           NaN
# 2      NaN       NaN          NaN      NaN           NaN           NaN
# 3    False        []          NaN      NaN           NaN           NaN
# 4    False        []          NaN      NaN           NaN           NaN
# ..     ...       ...          ...      ...           ...           ...
# 977  False        []        other      NaN            []  3.077256e+17
# 978  False        []       coding      NaN            []  3.077256e+17
# 979  False        []       coding      NaN            []  3.077256e+17
# 980  False        []       coding      NaN            []  3.077256e+17
# 981  False        []       coding      NaN            []  3.077256e+17
#
#     guild.name             author.nick              created_at  edited_at
# 0          NaN                     NaN                     NaT        NaN
# 1          NaN                     NaN                     NaT        NaN
# 2          NaN                     NaN                     NaT        NaN
# 3          NaN                     NaN                     NaT        NaN
# 4          NaN                     NaN                     NaT        NaN
# ..         ...                     ...                     ...        ...
# 977    [TUFFF]                Lion Boy 2024-02-04 01:44:11.224        NaN
# 978    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:11.779        NaN
# 979    [TUFFF]           Biggie cheese 2024-02-04 01:44:12.764        NaN
# 980    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:22.551        NaN
# 981    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:29.770        NaN
#
# [982 rows x 16 columns]

# %%
# Take only messages with a known created_at value
df.dropna(subset=['created_at'])
df = df[df['created_at'].notnull()]
df
# Out:
#                           _id                              content  \
# 543  65aff70f6d307c823cfbfa26                                 test
# 544  65aff7376d307c823cfbfa27                  testing testing 123
# 545  65aff99984785e8ddfcb111c                                 test
# 546  65aff9aa892723f4c1070c41                              testing
# 547  65aff9cd892723f4c1070c42  I've literally bought books for you
# ..                        ...                                  ...
# 977  65beebecb078e9ee076ef5b8                                    😄
# 978  65beebecb078e9ee076ef5b9                                 test
# 979  65beebedb078e9ee076ef5ba                            fucka you
# 980  65beebf7b078e9ee076ef5bb           oh wow a biggie cheese bot
# 981  65beebfeb078e9ee076ef5bc                         That's fancy
#
#                       id author.global_name    author.name mention_everyone  \
# 543  1199477436413395217               Lion    lion4567714            False
# 544  1199477608014950483               Lion    lion4567714            False
# 545  1199480162530623559               Lion    lion4567714            False
# 546  1199480233682812988               Lion    lion4567714            False
# 547  1199480380772847667      TheBugMonster  thebugmonster            False
# ..                   ...                ...            ...              ...
# 977  1203516321191436298               Lion    lion4567714            False
# 978  1203516323519533086            Huskies        husk1es            False
# 979  1203516327650918444      TheBugMonster  thebugmonster            False
# 980  1203516368700440597            Huskies        husk1es            False
# 981  1203516398979125289            Huskies        husk1es            False
#
#     pinned reactions channel.name mentions role_mentions      guild.id  \
# 543  False        []      general      NaN            []  9.762517e+17
# 544  False        []       coding      NaN            []  3.077256e+17
# 545  False        []      general      NaN            []  9.762517e+17
# 546  False        []      general      NaN            []  9.762517e+17
# 547  False        []       school      NaN            []  3.077256e+17
# ..     ...       ...          ...      ...           ...           ...
# 977  False        []        other      NaN            []  3.077256e+17
# 978  False        []       coding      NaN            []  3.077256e+17
# 979  False        []       coding      NaN            []  3.077256e+17
# 980  False        []       coding      NaN            []  3.077256e+17
# 981  False        []       coding      NaN            []  3.077256e+17
#
#     guild.name             author.nick              created_at  edited_at
# 543  Bot Harem                    None 2024-01-23 22:15:06.054        NaN
# 544    [TUFFF]                Lion Boy 2024-01-23 22:15:46.967        NaN
# 545  Bot Harem                    None 2024-01-23 22:25:56.011        NaN
# 546  Bot Harem                    None 2024-01-23 22:26:12.975        NaN
# 547    [TUFFF]           Biggie cheese 2024-01-23 22:26:48.044        NaN
# ..         ...                     ...                     ...        ...
# 977    [TUFFF]                Lion Boy 2024-02-04 01:44:11.224        NaN
# 978    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:11.779        NaN
# 979    [TUFFF]           Biggie cheese 2024-02-04 01:44:12.764        NaN
# 980    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:22.551        NaN
# 981    [TUFFF]  ${recipient_last_name} 2024-02-04 01:44:29.770        NaN
#
# [410 rows x 16 columns]
