# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

import pandas as pd

# %%
pd.set_option('display.max_rows', 25)

# %%
file = open('../config/mongo', 'r')
mongo = file.read().splitlines()
file.close()
uri = f"mongodb+srv://{mongo[0]}:{mongo[1]}@discordcluster.ujcowjs.mongodb.net/?retryWrites=true&w=majority"
mongo_client = MongoClient(uri, server_api=ServerApi('1'))
db = mongo_client.my_database
db = db.posts

# %%
df = pd.DataFrame(list(db.find()))

# %%
df
# Out:
#                           _id  \
# 0    65aec59ab34d51f31e7205e4
# 1    65aec5a0b34d51f31e7205e5
# 2    65aec5a1b34d51f31e7205e6
# 3    65aec961486a2b37a86a6859
# 4    65aec961486a2b37a86a685a
# ..                        ...
# 650  65b181d6f7f802b32767ed28
# 651  65b181e0f7f802b32767ed29
# 652  65b18251f7f802b32767ed2a
# 653  65b1825df7f802b32767ed2b
# 654  65b18262f7f802b32767ed2c
#
#                                               content                   id  \
# 0                                                test  1199077135063732365
# 1                                              $hello  1199077159969509407
# 2                                              Hello!  1199077161085181995
# 3                                              $hello  1199081188468469860
# 4                                              Hello!  1199081189739335680
# ..                                                ...                  ...
# 650                                         It's ours  1199871927213359187
# 651                                             Noice  1199871969009598554
# 652  Idk but I think this is a good range for the lab  1199872442101936280
# 653                             67.999->68.005->67.99  1199872494975340564
# 654                    That's some good fucking range  1199872513484795944
#
#     author.global_name    author.name mention_everyone pinned reactions  \
# 0                  NaN            NaN              NaN    NaN       NaN
# 1                  NaN            NaN              NaN    NaN       NaN
# 2                  NaN            NaN              NaN    NaN       NaN
# 3                 Lion    lion4567714            False  False        []
# 4                 None       Lion Bot            False  False        []
# ..                 ...            ...              ...    ...       ...
# 650      TheBugMonster  thebugmonster            False  False        []
# 651         BC_Stryker   bruh_stryker            False  False        []
# 652      TheBugMonster  thebugmonster            False  False        []
# 653      TheBugMonster  thebugmonster            False  False        []
# 654      TheBugMonster  thebugmonster            False  False        []
#
#     channel.name mentions role_mentions      guild.id guild.name  \
# 0            NaN      NaN           NaN           NaN        NaN
# 1            NaN      NaN           NaN           NaN        NaN
# 2            NaN      NaN           NaN           NaN        NaN
# 3            NaN      NaN           NaN           NaN        NaN
# 4            NaN      NaN           NaN           NaN        NaN
# ..           ...      ...           ...           ...        ...
# 650      general      NaN            []  3.077256e+17    [TUFFF]
# 651      general      NaN            []  3.077256e+17    [TUFFF]
# 652      general      NaN            []  3.077256e+17    [TUFFF]
# 653      general      NaN            []  3.077256e+17    [TUFFF]
# 654      general      NaN            []  3.077256e+17    [TUFFF]
#
#                      author.nick              created_at  edited_at
# 0                            NaN                     NaT        NaN
# 1                            NaN                     NaT        NaN
# 2                            NaN                     NaT        NaN
# 3                            NaN                     NaT        NaN
# 4                            NaN                     NaT        NaN
# ..                           ...                     ...        ...
# 650                Biggie cheese 2024-01-25 00:22:39.990        NaN
# 651  Business Major (Drone User) 2024-01-25 00:22:49.955        NaN
# 652                Biggie cheese 2024-01-25 00:24:42.749        NaN
# 653                Biggie cheese 2024-01-25 00:24:55.355        NaN
# 654                Biggie cheese 2024-01-25 00:24:59.768        NaN
#
# [655 rows x 16 columns]

# %%
# Take only messages with a known created_at value
df.dropna(subset=['created_at'])
df = df[df['created_at'].notnull()]
df
# Out:
#                           _id  \
# 543  65aff70f6d307c823cfbfa26
# 544  65aff7376d307c823cfbfa27
# 545  65aff99984785e8ddfcb111c
# 546  65aff9aa892723f4c1070c41
# 547  65aff9cd892723f4c1070c42
# ..                        ...
# 650  65b181d6f7f802b32767ed28
# 651  65b181e0f7f802b32767ed29
# 652  65b18251f7f802b32767ed2a
# 653  65b1825df7f802b32767ed2b
# 654  65b18262f7f802b32767ed2c
#
#                                               content                   id  \
# 543                                              test  1199477436413395217
# 544                               testing testing 123  1199477608014950483
# 545                                              test  1199480162530623559
# 546                                           testing  1199480233682812988
# 547               I've literally bought books for you  1199480380772847667
# ..                                                ...                  ...
# 650                                         It's ours  1199871927213359187
# 651                                             Noice  1199871969009598554
# 652  Idk but I think this is a good range for the lab  1199872442101936280
# 653                             67.999->68.005->67.99  1199872494975340564
# 654                    That's some good fucking range  1199872513484795944
#
#     author.global_name    author.name mention_everyone pinned reactions  \
# 543               Lion    lion4567714            False  False        []
# 544               Lion    lion4567714            False  False        []
# 545               Lion    lion4567714            False  False        []
# 546               Lion    lion4567714            False  False        []
# 547      TheBugMonster  thebugmonster            False  False        []
# ..                 ...            ...              ...    ...       ...
# 650      TheBugMonster  thebugmonster            False  False        []
# 651         BC_Stryker   bruh_stryker            False  False        []
# 652      TheBugMonster  thebugmonster            False  False        []
# 653      TheBugMonster  thebugmonster            False  False        []
# 654      TheBugMonster  thebugmonster            False  False        []
#
#     channel.name mentions role_mentions      guild.id guild.name  \
# 543      general      NaN            []  9.762517e+17  Bot Harem
# 544       coding      NaN            []  3.077256e+17    [TUFFF]
# 545      general      NaN            []  9.762517e+17  Bot Harem
# 546      general      NaN            []  9.762517e+17  Bot Harem
# 547       school      NaN            []  3.077256e+17    [TUFFF]
# ..           ...      ...           ...           ...        ...
# 650      general      NaN            []  3.077256e+17    [TUFFF]
# 651      general      NaN            []  3.077256e+17    [TUFFF]
# 652      general      NaN            []  3.077256e+17    [TUFFF]
# 653      general      NaN            []  3.077256e+17    [TUFFF]
# 654      general      NaN            []  3.077256e+17    [TUFFF]
#
#                      author.nick              created_at  edited_at
# 543                         None 2024-01-23 22:15:06.054        NaN
# 544                     Lion Boy 2024-01-23 22:15:46.967        NaN
# 545                         None 2024-01-23 22:25:56.011        NaN
# 546                         None 2024-01-23 22:26:12.975        NaN
# 547                Biggie cheese 2024-01-23 22:26:48.044        NaN
# ..                           ...                     ...        ...
# 650                Biggie cheese 2024-01-25 00:22:39.990        NaN
# 651  Business Major (Drone User) 2024-01-25 00:22:49.955        NaN
# 652                Biggie cheese 2024-01-25 00:24:42.749        NaN
# 653                Biggie cheese 2024-01-25 00:24:55.355        NaN
# 654                Biggie cheese 2024-01-25 00:24:59.768        NaN
#
# [112 rows x 16 columns]
